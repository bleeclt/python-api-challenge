# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import time

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
weather_df = pd.read_csv("../output_data/weather_df.csv")
weather_df
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Avarua -21.21 -159.78     69.80        88         100        3.36
# 1    Provideniya  64.38 -173.30     28.98        96          97        4.52
# 2         Murgab  37.50   61.97     55.40        50           0        9.17
# 3      Geraldton -28.77  114.60     60.80        77          40        8.05
# 4      Busselton -33.65  115.33     60.01        74          66        9.78
# ..           ...    ...     ...       ...       ...         ...         ...
# 511      Klyuchi  52.27   79.17     35.17        79          19       19.10
# 512     San Jose  37.34 -121.89     73.99        19           0        3.22
# 513   Kaitangata -46.28  169.85     42.80        89          12        2.13
# 514        Ukiah  39.15 -123.21     75.99        25           1        3.36
# 515  Clyde River  70.47  -68.59     14.00        61          75        6.93
#
#     Country        Date
# 0        CK  1603823838
# 1        RU  1603823840
# 2        TM  1603823842
# 3        AU  1603823844
# 4        AU  1603823846
# ..      ...         ...
# 511      RU  1603825476
# 512      US  1603825407
# 513      NZ  1603824772
# 514      US  1603825068
# 515      CA  1603824933
#
# [516 rows x 9 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# config gmaps
gmaps.configure(api_key = g_key)

# locations variable to store lat and lng
locations = weather_df[["Lat", "Lng"]]

# use weight variable for Humidity
weight = weather_df["Humidity"]

fig = gmaps.figure()

heatmap_layer = gmaps.heatmap_layer(locations, weights=weight,
                                   dissipating=False, max_intensity=5,
                                   point_radius=1)

fig.add_layer(heatmap_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
# Narrow down the DataFrame to fit ideal weather conditions
# A max temperature lower than 80 degrees but higher than 70.
# Wind speed less than 15 mph.
# Drop rows that don't contain above. 

# new dataframe for specific weather
ideal_weather_df = weather_df.loc[(weather_df["Wind Speed"] <= 15) & (weather_df["Max Temp"] > 70) & (weather_df["Max Temp"] < 80)].dropna()


# cities with ideal weather dataframe
ideal_weather_df
# Out:
#                City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 9    Saint-Philippe -21.36   55.77     75.20        73          20
# 13            Kapaa  22.08 -159.32     73.99        83          90
# 14    Kasongo-Lunda  -6.47   16.82     73.11        91          33
# 26   Saint-Philippe -21.36   55.77     75.20        73          20
# 30            Kapaa  22.08 -159.32     73.99        83          90
# ..              ...    ...     ...       ...       ...         ...
# 492          Owando  -0.48   15.90     73.92        94         100
# 498          Playas  -2.63  -80.38     74.34        75          48
# 508       Sassandra   4.95   -6.08     77.79        86          13
# 512        San Jose  37.34 -121.89     73.99        19           0
# 514           Ukiah  39.15 -123.21     75.99        25           1
#
#      Wind Speed Country        Date
# 9          3.36      RE  1603823857
# 13         5.82      US  1603823866
# 14         1.92      CD  1603823868
# 26         3.36      RE  1603823857
# 30         5.82      US  1603823866
# ..          ...     ...         ...
# 492        1.05      CG  1603825416
# 498       13.44      EC  1603825435
# 508        5.88      CI  1603825466
# 512        3.22      US  1603825407
# 514        3.36      US  1603825068
#
# [113 rows x 9 columns]

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
# create hotel dataframe with city, country, latitude and longitude
hotel_df = pd.DataFrame(weather_df, columns=["City", "Country", "Lat", "Lng"])

# create Hotel Name column to populate
hotel_df["Hotel Name"] = ""

hotel_df
# Out:
#             City Country    Lat     Lng Hotel Name
# 0         Avarua      CK -21.21 -159.78
# 1    Provideniya      RU  64.38 -173.30
# 2         Murgab      TM  37.50   61.97
# 3      Geraldton      AU -28.77  114.60
# 4      Busselton      AU -33.65  115.33
# ..           ...     ...    ...     ...        ...
# 511      Klyuchi      RU  52.27   79.17
# 512     San Jose      US  37.34 -121.89
# 513   Kaitangata      NZ -46.28  169.85
# 514        Ukiah      US  39.15 -123.21
# 515  Clyde River      CA  70.47  -68.59
#
# [516 rows x 5 columns]

# %%
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# parameters to search
params = {"type" : "hotel",
          "keyword" : "hotel",
          "radius" : 5000,
          "key" : g_key}

for index, row in hotel_df.iterrows():
    # get city name, lat, lnt from df
    lat = row["Lat"]
    lng = row["Lng"]
    city_name = row["City"]
    
    # add keyword to params dict
    params["location"] = f"{lat},{lng}"

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {city_name}.")
    response = requests.get(base_url, params=params).json()
    
    # extract results
    results = response['results']
    
    # save the hotel name to dataframe
    try:
        print(f"Closest hotel in {city_name} is {results[0]['name']}.")
        hotel_df.loc[index, "Hotel Name"] = results[0]['name']

    # if there is no hotel available, show missing field
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    print("------------")
    
    # add 2 second delay to api request
    time.sleep(2)
    
# Print end of search once searching is completed
print("-------End of Search-------")
# Out:
# Retrieving Results for Index 0: Avarua.
# Closest hotel in Avarua is The Edgewater Resort and Spa.
# ------------
# Retrieving Results for Index 1: Provideniya.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 2: Murgab.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 3: Geraldton.
# Closest hotel in Geraldton is Ocean Centre Hotel.
# ------------
# Retrieving Results for Index 4: Busselton.
# Closest hotel in Busselton is Esplanade Hotel.
# ------------
# Retrieving Results for Index 5: Cherskiy.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 6: Nikolskoye.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 7: Mount Isa.
# Closest hotel in Mount Isa is Isa Hotel.
# ------------
# Retrieving Results for Index 8: Puerto Escondido.
# Closest hotel in Puerto Escondido is Selina Puerto Escondido.
# ------------
# Retrieving Results for Index 9: Saint-Philippe.
# Closest hotel in Saint-Philippe is Les Embruns Du Baril.
# ------------
# Retrieving Results for Index 10: Mataura.
# Closest hotel in Mataura is Southland Organic Farmstay.
# ------------
# Retrieving Results for Index 11: Arraial do Cabo.
# Closest hotel in Arraial do Cabo is Orlanova Boutique Hotel.
# ------------
# Retrieving Results for Index 12: Iqaluit.
# Closest hotel in Iqaluit is Frobisher Inn.
# ------------
# Retrieving Results for Index 13: Kapaa.
# Closest hotel in Kapaa is The ISO.
# ------------
# Retrieving Results for Index 14: Kasongo-Lunda.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 15: Cape Town.
# Closest hotel in Cape Town is Atlanticview Cape Town Boutique Hotel.
# ------------
# Retrieving Results for Index 16: Okahandja.
# Closest hotel in Okahandja is Okahandja Lodge.
# ------------
# Retrieving Results for Index 17: Avarua.
# Closest hotel in Avarua is The Edgewater Resort and Spa.
# ------------
# Retrieving Results for Index 18: Provideniya.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 19: Murgab.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 20: Geraldton.
# Closest hotel in Geraldton is Ocean Centre Hotel.
# ------------
# Retrieving Results for Index 21: Busselton.
# Closest hotel in Busselton is Esplanade Hotel.
# ------------
# Retrieving Results for Index 22: Cherskiy.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 23: Nikolskoye.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 24: Mount Isa.
# Closest hotel in Mount Isa is Isa Hotel.
# ------------
# Retrieving Results for Index 25: Puerto Escondido.
# Closest hotel in Puerto Escondido is Selina Puerto Escondido.
# ------------
# Retrieving Results for Index 26: Saint-Philippe.
# Closest hotel in Saint-Philippe is Les Embruns Du Baril.
# ------------
# Retrieving Results for Index 27: Mataura.
# Closest hotel in Mataura is Southland Organic Farmstay.
# ------------
# Retrieving Results for Index 28: Arraial do Cabo.
# Closest hotel in Arraial do Cabo is Orlanova Boutique Hotel.
# ------------
# Retrieving Results for Index 29: Iqaluit.
# Closest hotel in Iqaluit is Frobisher Inn.
# ------------
# Retrieving Results for Index 30: Kapaa.
# Closest hotel in Kapaa is The ISO.
# ------------
# Retrieving Results for Index 31: Kasongo-Lunda.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 32: Cape Town.
# Closest hotel in Cape Town is Atlanticview Cape Town Boutique Hotel.
# ------------
# Retrieving Results for Index 33: Okahandja.
# Closest hotel in Okahandja is Okahandja Lodge.
# ------------
# Retrieving Results for Index 34: Puerto Ayora.
# Closest hotel in Puerto Ayora is Finch Bay Galapagos Hotel.
# ------------
# Retrieving Results for Index 35: Hofn.
# Closest hotel in Hofn is Hótel Höfn.
# ------------
# Retrieving Results for Index 36: Dikson.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 37: Hithadhoo.
# Closest hotel in Hithadhoo is Bloomy Inn.
# ------------
# Retrieving Results for Index 38: Neijiang.
# Closest hotel in Neijiang is 内江万达嘉华酒店.
# ------------
# Retrieving Results for Index 39: Malartic.
# Closest hotel in Malartic is Motel Morin.
# ------------
# Retrieving Results for Index 40: Udachny.
# Closest hotel in Udachny is Гостиница СЕВЕРНОЕ СИЯНИЕ.
# ------------
# Retrieving Results for Index 41: Muravlenko.
# Closest hotel in Muravlenko is E-Hotel Muravlenko.
# ------------
# Retrieving Results for Index 42: Hasaki.
# Closest hotel in Hasaki is 別邸 海と森.
# ------------
# Retrieving Results for Index 43: Radomsko.
# Closest hotel in Radomsko is Hotel Porto.
# ------------
# Retrieving Results for Index 44: Barrow.
# Closest hotel in Barrow is Top of the World Hotel.
# ------------
# Retrieving Results for Index 45: Dakar.
# Closest hotel in Dakar is Radisson Blu Hotel, Dakar Sea Plaza.
# ------------
# Retrieving Results for Index 46: East London.
# Closest hotel in East London is Blue Lagoon Hotel.
# ------------
# Retrieving Results for Index 47: Siavonga.
# Closest hotel in Siavonga is Lake Kariba Inns.
# ------------
# Retrieving Results for Index 48: Butaritari.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 49: Kruisfontein.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 50: Brandenburg.
# Closest hotel in Brandenburg is SEEHOTEL Brandenburg a.d. Havel.
# ------------
# Retrieving Results for Index 51: San Juan.
# Closest hotel in San Juan is Hotel Viñas del Sol.
# ------------
# Retrieving Results for Index 52: Vostok.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 53: Sirtich.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 54: Hobart.
# Closest hotel in Hobart is The Henry Jones Art Hotel.
# ------------
# Retrieving Results for Index 55: Lüderitz.
# Closest hotel in Lüderitz is LÜDERITZ NEST HOTEL.
# ------------
# Retrieving Results for Index 56: Stokmarknes.
# Closest hotel in Stokmarknes is Vesterålen Kysthotell.
# ------------
# Retrieving Results for Index 57: George Town.
# Closest hotel in George Town is Eastern & Oriental Hotel, Penang.
# ------------
# Retrieving Results for Index 58: Hilo.
# Closest hotel in Hilo is Grand Naniloa Hotel Hilo - a DoubleTree by Hilton.
# ------------
# Retrieving Results for Index 59: Kwinana.
# Closest hotel in Kwinana is Quest Rockingham.
# ------------
# Retrieving Results for Index 60: New Norfolk.
# Closest hotel in New Norfolk is Tynwald Willow Bend Estate.
# ------------
# Retrieving Results for Index 61: Horki.
# Closest hotel in Horki is Gostinitsa.
# ------------
# Retrieving Results for Index 62: Yellowknife.
# Closest hotel in Yellowknife is The Explorer Hotel.
# ------------
# Retrieving Results for Index 63: Olafsvik.
# Closest hotel in Olafsvik is Við Hafið Guesthouse.
# ------------
# Retrieving Results for Index 64: Korla.
# Closest hotel in Korla is The Garden Hotel Korla.
# ------------
# Retrieving Results for Index 65: Hermanus.
# Closest hotel in Hermanus is Harbour House Hotel.
# ------------
# Retrieving Results for Index 66: Maceió.
# Closest hotel in Maceió is Jatiúca Hotel & Resort.
# ------------
# Retrieving Results for Index 67: Pineville.
# Closest hotel in Pineville is The Hotel Bentley of Alexandria.
# ------------
# Retrieving Results for Index 68: Quatre Cocos.
# Closest hotel in Quatre Cocos is Shangri-La's Le Touessrok Resort & Spa.
# ------------
# Retrieving Results for Index 69: The Valley.
# Closest hotel in The Valley is Zemi Beach House, LXR Hotels & Resorts.
# ------------
# Retrieving Results for Index 70: Chumikan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 71: Calbe.
# Closest hotel in Calbe is AKZENT Hotel Acamed Resort - Erlebnis- & Wellnesshotel.
# ------------
# Retrieving Results for Index 72: Mount Gambier.
# Closest hotel in Mount Gambier is Commodore on the Park.
# ------------
# Retrieving Results for Index 73: Cabo San Lucas.
# Closest hotel in Cabo San Lucas is Waldorf Astoria Los Cabos Pedregal.
# ------------
# Retrieving Results for Index 74: Saint George.
# Closest hotel in Saint George is The Advenire, Autograph Collection.
# ------------
# Retrieving Results for Index 75: Tasiilaq.
# Closest hotel in Tasiilaq is Hotel Angmagssalik.
# ------------
# Retrieving Results for Index 76: Khajuraho.
# Closest hotel in Khajuraho is SYNA Heritage Hotel - A Heritage Hotel in Khajuraho.
# ------------
# Retrieving Results for Index 77: Norman Wells.
# Closest hotel in Norman Wells is Heritage Hotel.
# ------------
# Retrieving Results for Index 78: Margate.
# Closest hotel in Margate is Walpole Bay Hotel.
# ------------
# Retrieving Results for Index 79: Morondava.
# Closest hotel in Morondava is Palissandre Cote Ouest resort & SPA.
# ------------
# Retrieving Results for Index 80: Albany.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 81: Rikitea.
# Closest hotel in Rikitea is Pension Bianca & Benoit.
# ------------
# Retrieving Results for Index 82: São Filipe.
# Closest hotel in São Filipe is Casas Do Sol.
# ------------
# Retrieving Results for Index 83: Katsuura.
# Closest hotel in Katsuura is Katsuura Hotel Mikazuki.
# ------------
# Retrieving Results for Index 84: Ushuaia.
# Closest hotel in Ushuaia is Hotel Los Yámanas.
# ------------
# Retrieving Results for Index 85: Banda Aceh.
# Closest hotel in Banda Aceh is Hermes Palace Hotel Banda Aceh.
# ------------
# Retrieving Results for Index 86: Baculin.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 87: Cidreira.
# Closest hotel in Cidreira is Hotel Castelo.
# ------------
# Retrieving Results for Index 88: Narsaq.
# Closest hotel in Narsaq is Hotel Narsaq.
# ------------
# Retrieving Results for Index 89: Hong Kong.
# Closest hotel in Hong Kong is Rosedale Hotel Kowloon.
# ------------
# Retrieving Results for Index 90: Port Alfred.
# Closest hotel in Port Alfred is Royal St Andrews Hotel.
# ------------
# Retrieving Results for Index 91: Bathsheba.
# Closest hotel in Bathsheba is Atlantis Hotel.
# ------------
# Retrieving Results for Index 92: Robertsport.
# Closest hotel in Robertsport is Nana's Lodge.
# ------------
# Retrieving Results for Index 93: Pevek.
# Closest hotel in Pevek is Munitsipal'naya Gostinitsa.
# ------------
# Retrieving Results for Index 94: Faya.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 95: Jamestown.
# Closest hotel in Jamestown is Chautauqua Harbor Hotel.
# ------------
# Retrieving Results for Index 96: Saint Paul Harbor.
# Closest hotel in Saint Paul Harbor is Best Western Kodiak Inn and Convention Center.
# ------------
# Retrieving Results for Index 97: Chui.
# Closest hotel in Chui is Turis Firper Hotel.
# ------------
# Retrieving Results for Index 98: Marsh Harbour.
# Closest hotel in Marsh Harbour is Abaco Beach Resort.
# ------------
# Retrieving Results for Index 99: Punta Arenas.
# Closest hotel in Punta Arenas is Hotel Cabo de Hornos.
# ------------
# Retrieving Results for Index 100: Lake Charles.
# Closest hotel in Lake Charles is Courtyard by Marriott Lake Charles.
# ------------
# Retrieving Results for Index 101: Cascais.
# Closest hotel in Cascais is Hotel Inglaterra Estoril.
# ------------
# Retrieving Results for Index 102: Alma.
# Closest hotel in Alma is Hotel Universel.
# ------------
# Retrieving Results for Index 103: Ponta do Sol.
# Closest hotel in Ponta do Sol is Estalagem Da Ponta Do Sol.
# ------------
# Retrieving Results for Index 104: Grand Gaube.
# Closest hotel in Grand Gaube is LUX Grand Gaube Resort & Villas.
# ------------
# Retrieving Results for Index 105: Buluang.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 106: Jalu.
# Closest hotel in Jalu is Jalu Hotel.
# ------------
# Retrieving Results for Index 107: Avera.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 108: Uvinza.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 109: Katobu.
# Closest hotel in Katobu is La Ode Husein.
# ------------
# Retrieving Results for Index 110: Shimoda.
# Closest hotel in Shimoda is Gardenvilla Shirahama.
# ------------
# Retrieving Results for Index 111: Santa Rosa.
# Closest hotel in Santa Rosa is El Cielito Hotel - Sta. Rosa.
# ------------
# Retrieving Results for Index 112: Ntungamo.
# Closest hotel in Ntungamo is The Crested Crane Bwindi Hotel.
# ------------
# Retrieving Results for Index 113: Altay.
# Closest hotel in Altay is dan dan hotel.
# ------------
# Retrieving Results for Index 114: Puerto Ayacucho.
# Closest hotel in Puerto Ayacucho is Hotel Perimetral.
# ------------
# Retrieving Results for Index 115: South Kazakhstan Region.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 116: Tura.
# Closest hotel in Tura is Hotel Polo Orchid.
# ------------
# Retrieving Results for Index 117: Isabela.
# Closest hotel in Isabela is Basilan Business Hotel.
# ------------
# Retrieving Results for Index 118: North Port.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 119: Bengkulu.
# Closest hotel in Bengkulu is Mercure Bengkulu.
# ------------
# Retrieving Results for Index 120: Elko.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 121: Felipe Carrillo Puerto.
# Closest hotel in Felipe Carrillo Puerto is Hotel Turquesa Maya.
# ------------
# Retrieving Results for Index 122: Bluff.
# Closest hotel in Bluff is Land's End Boutique Hotel.
# ------------
# Retrieving Results for Index 123: Belen.
# Closest hotel in Belen is Varlıbaş Uyku Sarayı.
# ------------
# Retrieving Results for Index 124: Shulan.
# Closest hotel in Shulan is Jinzhou Hotel.
# ------------
# Retrieving Results for Index 125: Makakilo City.
# Closest hotel in Makakilo City is Marriott's Ko Olina Beach Club.
# ------------
# Retrieving Results for Index 126: Khatanga.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 127: Jackson.
# Closest hotel in Jackson is Best Western Crater Lake Highway White City/Medford.
# ------------
# Retrieving Results for Index 128: Bredasdorp.
# Closest hotel in Bredasdorp is De Hoop Collection.
# ------------
# Retrieving Results for Index 129: Cockburn Town.
# Closest hotel in Cockburn Town is Bohio Dive Resort.
# ------------
# Retrieving Results for Index 130: Rawson.
# Closest hotel in Rawson is Hotel Punta León.
# ------------
# Retrieving Results for Index 131: Linfen.
# Closest hotel in Linfen is Jindu Garden Grand Hotel.
# ------------
# Retrieving Results for Index 132: Finschhafen.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 133: Stanislav.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 134: Sokolo.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 135: Faanui.
# Closest hotel in Faanui is InterContinental Bora Bora Resort Thalasso Spa.
# ------------
# Retrieving Results for Index 136: Fairbanks.
# Closest hotel in Fairbanks is SpringHill Suites by Marriott Fairbanks.
# ------------
# Retrieving Results for Index 137: Payo.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 138: Biak.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 139: Tessalit.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 140: Lorengau.
# Closest hotel in Lorengau is Lorengau Harbourside Hotel.
# ------------
# Retrieving Results for Index 141: Luwuk.
# Closest hotel in Luwuk is Swiss-Belinn Hotel Luwuk.
# ------------
# Retrieving Results for Index 142: Bambous Virieux.
# Closest hotel in Bambous Virieux is Laguna Beach Hotel & Spa.
# ------------
# Retrieving Results for Index 143: Hambantota.
# Closest hotel in Hambantota is Jade Green Hotel Hambantota.
# ------------
# Retrieving Results for Index 144: Green.
# Closest hotel in Green is Quality Inn.
# ------------
# Retrieving Results for Index 145: Qaanaaq.
# Closest hotel in Qaanaaq is Qaanaaq Hotel.
# ------------
# Retrieving Results for Index 146: Itamaracá.
# Closest hotel in Itamaracá is Pousada Ruínas do Pilar.
# ------------
# Retrieving Results for Index 147: Blackwater.
# Closest hotel in Blackwater is Blackwater Central Motel.
# ------------
# Retrieving Results for Index 148: Rumuruti.
# Closest hotel in Rumuruti is Elparaiso bar and restaurant.
# ------------
# Retrieving Results for Index 149: Atuona.
# Closest hotel in Atuona is Hôtel Hiva Oa Hanakee Lodge.
# ------------
# Retrieving Results for Index 150: Kiknur.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 151: Viçosa do Ceará.
# Closest hotel in Viçosa do Ceará is Viçosa Hotel de Serra.
# ------------
# Retrieving Results for Index 152: Thompson.
# Closest hotel in Thompson is Best Western Thompson Hotel & Suites.
# ------------
# Retrieving Results for Index 153: Port Macquarie.
# Closest hotel in Port Macquarie is Sails Port Macquarie by Rydges.
# ------------
# Retrieving Results for Index 154: Lodja.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 155: Lata.
# Closest hotel in Lata is Magnolias Cottage.
# ------------
# Retrieving Results for Index 156: Carnarvon.
# Closest hotel in Carnarvon is Carnarvon Sea Change Apartments.
# ------------
# Retrieving Results for Index 157: Tabriz.
# Closest hotel in Tabriz is Sina Hotel.
# ------------
# Retrieving Results for Index 158: Ascension.
# Closest hotel in Ascension is Home2 Suites By Hilton Gonzales.
# ------------
# Retrieving Results for Index 159: Constitución.
# Closest hotel in Constitución is Reserva los Bollenes.
# ------------
# Retrieving Results for Index 160: Lompoc.
# Closest hotel in Lompoc is Hilton Garden Inn Lompoc.
# ------------
# Retrieving Results for Index 161: Chokurdakh.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 162: Saskylakh.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 163: Vysha.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 164: Souillac.
# Closest hotel in Souillac is SkylineInn Hotel.
# ------------
# Retrieving Results for Index 165: Jiayuguan City.
# Closest hotel in Jiayuguan City is Jiayuguan Hotel.
# ------------
# Retrieving Results for Index 166: Tabou.
# Closest hotel in Tabou is hotêl doufoulougou.
# ------------
# Retrieving Results for Index 167: Tuatapere.
# Closest hotel in Tuatapere is Last Light Lodge.
# ------------
# Retrieving Results for Index 168: Severo-Kuril'sk.
# Closest hotel in Severo-Kuril'sk is Kak Doma.
# ------------
# Retrieving Results for Index 169: Kasangulu.
# Closest hotel in Kasangulu is Hôtel Annie Tshiama.
# ------------
# Retrieving Results for Index 170: Ribeira Grande.
# Closest hotel in Ribeira Grande is Quinta Das Buganvílias.
# ------------
# Retrieving Results for Index 171: Gorahun.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 172: Middelburg.
# Closest hotel in Middelburg is Alveston Manor Small Hotel.
# ------------
# Retrieving Results for Index 173: Batagay.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 174: Sawākin.
# Closest hotel in Sawākin is Arab Plaza Hotel عرب بلازا هوتيل.
# ------------
# Retrieving Results for Index 175: Sol'-Iletsk.
# Closest hotel in Sol'-Iletsk is Gostinitsa Na Pushkina.
# ------------
# Retrieving Results for Index 176: Okhotsk.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 177: Cayenne.
# Closest hotel in Cayenne is Royal Amazonia.
# ------------
# Retrieving Results for Index 178: Kirishi.
# Closest hotel in Kirishi is Sportivnaya.
# ------------
# Retrieving Results for Index 179: Asekeyevo.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 180: Kiryat Gat.
# Closest hotel in Kiryat Gat is Desert Gat.
# ------------
# Retrieving Results for Index 181: Lima.
# Closest hotel in Lima is Golden vox hotel suite.
# ------------
# Retrieving Results for Index 182: Hailar.
# Closest hotel in Hailar is Holiday Inn & Suites Hulunbuir.
# ------------
# Retrieving Results for Index 183: Peleduy.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 184: Saldanha.
# Closest hotel in Saldanha is Hoedjiesbaai Hotel.
# ------------
# Retrieving Results for Index 185: Lumut.
# Closest hotel in Lumut is Swiss-Garden Beach Resort Damai Laut.
# ------------
# Retrieving Results for Index 186: Tessaoua.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 187: Ol'ga.
# Closest hotel in Ol'ga is Gostinitsa.
# ------------
# Retrieving Results for Index 188: Lamar.
# Closest hotel in Lamar is Old Magnolia House Bed & Breakfast.
# ------------
# Retrieving Results for Index 189: Longyearbyen.
# Closest hotel in Longyearbyen is Radisson Blu Polar Hotel, Spitsbergen.
# ------------
# Retrieving Results for Index 190: Whitehorse.
# Closest hotel in Whitehorse is Best Western Gold Rush Inn.
# ------------
# Retrieving Results for Index 191: Biu.
# Closest hotel in Biu is Biu Luxury Motel and Suites.
# ------------
# Retrieving Results for Index 192: Henties Bay.
# Closest hotel in Henties Bay is Desert Rose.
# ------------
# Retrieving Results for Index 193: Khovd.
# Closest hotel in Khovd is Steppe hotel.
# ------------
# Retrieving Results for Index 194: Catuday.
# Closest hotel in Catuday is Veue Beach Cabins.
# ------------
# Retrieving Results for Index 195: College.
# Closest hotel in College is 7 Gables Inn & Suites.
# ------------
# Retrieving Results for Index 196: Kayerkan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 197: Province of Trapani.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 198: La Trinitaria.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 199: Gijang.
# Closest hotel in Gijang is Hilton Busan.
# ------------
# Retrieving Results for Index 200: Maridi.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 201: Kamaishi.
# Closest hotel in Kamaishi is Hotel Folkloro Sanriku Kamaishi.
# ------------
# Retrieving Results for Index 202: Sorrento.
# Closest hotel in Sorrento is Hotel Mega Mare.
# ------------
# Retrieving Results for Index 203: Kahului.
# Closest hotel in Kahului is Maui Beach Hotel.
# ------------
# Retrieving Results for Index 204: Enshi.
# Closest hotel in Enshi is Moevenpick Enshi.
# ------------
# Retrieving Results for Index 205: Lebu.
# Closest hotel in Lebu is Hotel Plaza Lebu.
# ------------
# Retrieving Results for Index 206: Maniitsoq.
# Closest hotel in Maniitsoq is Hotel Heilmann Lyberth.
# ------------
# Retrieving Results for Index 207: Tuktoyaktuk.
# Closest hotel in Tuktoyaktuk is Hunter's B&B.
# ------------
# Retrieving Results for Index 208: Tilichiki.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 209: Japura.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 210: Akranes.
# Closest hotel in Akranes is Moar Guesthouse.
# ------------
# Retrieving Results for Index 211: Vaini.
# Closest hotel in Vaini is Paradise First Hotel.
# ------------
# Retrieving Results for Index 212: Kumul.
# Closest hotel in Kumul is 哈密环球大酒店.
# ------------
# Retrieving Results for Index 213: Ballina.
# Closest hotel in Ballina is Ramada Hotel & Suites by Wyndham Ballina Byron.
# ------------
# Retrieving Results for Index 214: Matara.
# Closest hotel in Matara is Deep Blue Sri Lanka Rentals.
# ------------
# Retrieving Results for Index 215: Shalyhyne.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 216: Byron Bay.
# Closest hotel in Byron Bay is Elements of Byron.
# ------------
# Retrieving Results for Index 217: Mar del Plata.
# Closest hotel in Mar del Plata is NH Gran Hotel Provincial.
# ------------
# Retrieving Results for Index 218: Port Huron.
# Closest hotel in Port Huron is DoubleTree by Hilton Hotel Port Huron.
# ------------
# Retrieving Results for Index 219: Sitka.
# Closest hotel in Sitka is Talon Lodge & Spa.
# ------------
# Retrieving Results for Index 220: Mabaruma.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 221: Tsimmerbude.
# Closest hotel in Tsimmerbude is Slavyanskiy Dvor.
# ------------
# Retrieving Results for Index 222: Brae.
# Closest hotel in Brae is Busta House Hotel.
# ------------
# Retrieving Results for Index 223: Port Keats.
# Closest hotel in Port Keats is TDC Village (Hundred Man Camp).
# ------------
# Retrieving Results for Index 224: Bubaque.
# Closest hotel in Bubaque is Ponta Anchaca.
# ------------
# Retrieving Results for Index 225: Port Lincoln.
# Closest hotel in Port Lincoln is Port Lincoln Hotel.
# ------------
# Retrieving Results for Index 226: Mocuba.
# Closest hotel in Mocuba is Pensão Venus.
# ------------
# Retrieving Results for Index 227: Ahipara.
# Closest hotel in Ahipara is Ahipara Bay Motel.
# ------------
# Retrieving Results for Index 228: Fortuna.
# Closest hotel in Fortuna is THE REDWOOD RIVERWALK HOTEL.
# ------------
# Retrieving Results for Index 229: Chitipa.
# Closest hotel in Chitipa is Tulipoka Lodges.
# ------------
# Retrieving Results for Index 230: Daru.
# Closest hotel in Daru is Daru hotel.
# ------------
# Retrieving Results for Index 231: Kainantu.
# Closest hotel in Kainantu is Nasuke GUEST House.
# ------------
# Retrieving Results for Index 232: Ladário.
# Closest hotel in Ladário is Hotel Gold fish corumbá MS.
# ------------
# Retrieving Results for Index 233: Emerald.
# Closest hotel in Emerald is Emerald Maraboon Motor Inn.
# ------------
# Retrieving Results for Index 234: Cristalina.
# Closest hotel in Cristalina is Ity Hotel.
# ------------
# Retrieving Results for Index 235: Paris.
# Closest hotel in Paris is Hotel Georgette.
# ------------
# Retrieving Results for Index 236: Sagua de Tánamo.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 237: Guerrero Negro.
# Closest hotel in Guerrero Negro is The Halfway Inn.
# ------------
# Retrieving Results for Index 238: Marawi.
# Closest hotel in Marawi is Marawi Resort Hotel.
# ------------
# Retrieving Results for Index 239: Ulundi.
# Closest hotel in Ulundi is Garden Court Ulundi.
# ------------
# Retrieving Results for Index 240: Mahébourg.
# Closest hotel in Mahébourg is Holiday Inn Mauritius Mon Tresor.
# ------------
# Retrieving Results for Index 241: Castro.
# Closest hotel in Castro is Buganville Palace Hotel.
# ------------
# Retrieving Results for Index 242: Los Llanos de Aridane.
# Closest hotel in Los Llanos de Aridane is Hotel Hacienda de Abajo.
# ------------
# Retrieving Results for Index 243: San Patricio.
# Closest hotel in San Patricio is Americas Best Value Inn Sinton.
# ------------
# Retrieving Results for Index 244: Lagoa.
# Closest hotel in Lagoa is Graciosa Resort - Biosphere Island Hotel.
# ------------
# Retrieving Results for Index 245: São Raimundo Nonato.
# Closest hotel in São Raimundo Nonato is Real Hotel.
# ------------
# Retrieving Results for Index 246: Vila do Maio.
# Closest hotel in Vila do Maio is Stella Maris.
# ------------
# Retrieving Results for Index 247: Meulaboh.
# Closest hotel in Meulaboh is Hotel Meuligoe.
# ------------
# Retrieving Results for Index 248: Vanderhoof.
# Closest hotel in Vanderhoof is Homestead Inn & Suites.
# ------------
# Retrieving Results for Index 249: Amuntai.
# Closest hotel in Amuntai is Minosa Resort Hotel.
# ------------
# Retrieving Results for Index 250: Muros.
# Closest hotel in Muros is Hotel La Muradana.
# ------------
# Retrieving Results for Index 251: Bud.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 252: Port Elizabeth.
# Closest hotel in Port Elizabeth is The Vic Boutique Hotel.
# ------------
# Retrieving Results for Index 253: Torbay.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 254: Eureka.
# Closest hotel in Eureka is Best Western Plus Humboldt Bay Inn.
# ------------
# Retrieving Results for Index 255: Gizo Government Station.
# Closest hotel in Gizo Government Station is Gizo Hotel.
# ------------
# Retrieving Results for Index 256: Sweetwater.
# Closest hotel in Sweetwater is NUVO SUITES HOTEL.
# ------------
# Retrieving Results for Index 257: Bodden Town.
# Closest hotel in Bodden Town is Evolution — Luxury Cayman Villas.
# ------------
# Retrieving Results for Index 258: Nuuk.
# Closest hotel in Nuuk is Hotel Hans Egede.
# ------------
# Retrieving Results for Index 259: Tiksi.
# Closest hotel in Tiksi is Arktika.
# ------------
# Retrieving Results for Index 260: Kaeo.
# Closest hotel in Kaeo is Pacific Harbour Lodge.
# ------------
# Retrieving Results for Index 261: Port Moresby.
# Closest hotel in Port Moresby is Hilton Port Moresby.
# ------------
# Retrieving Results for Index 262: Río Gallegos.
# Closest hotel in Río Gallegos is Hotel Patagonia.
# ------------
# Retrieving Results for Index 263: Upernavik.
# Closest hotel in Upernavik is Café de Upernavik.
# ------------
# Retrieving Results for Index 264: Uyskoye.
# Closest hotel in Uyskoye is Niva.
# ------------
# Retrieving Results for Index 265: San Cristobal.
# Closest hotel in San Cristobal is Lidotel Hotel Boutique San Cristobal.
# ------------
# Retrieving Results for Index 266: Evanston.
# Closest hotel in Evanston is Hilton Orrington/Evanston.
# ------------
# Retrieving Results for Index 267: Paso de Carrasco.
# Closest hotel in Paso de Carrasco is Hotel Sofitel Montevideo Casino Carrasco and Spa.
# ------------
# Retrieving Results for Index 268: Vao.
# Closest hotel in Vao is OURE TERA beach resort.
# ------------
# Retrieving Results for Index 269: Sabang.
# Closest hotel in Sabang is Casa Nemo Beach Resort & Spa.
# ------------
# Retrieving Results for Index 270: Ancud.
# Closest hotel in Ancud is Panamericana Hotel Ancud.
# ------------
# Retrieving Results for Index 271: Gravdal.
# Closest hotel in Gravdal is Scandic Leknes Lofoten Hotel.
# ------------
# Retrieving Results for Index 272: Itarema.
# Closest hotel in Itarema is White Wind Resort.
# ------------
# Retrieving Results for Index 273: Ugra.
# Closest hotel in Ugra is Gostinichnyy Kompleks Vizit.
# ------------
# Retrieving Results for Index 274: Laguna.
# Closest hotel in Laguna is Hilton Garden Inn Sacramento Elk Grove.
# ------------
# Retrieving Results for Index 275: Celestún.
# Closest hotel in Celestún is Playa 55 beach escape.
# ------------
# Retrieving Results for Index 276: Codrington.
# Closest hotel in Codrington is Codrington Gardens Bed And Breakfast.
# ------------
# Retrieving Results for Index 277: Mtwara.
# Closest hotel in Mtwara is Naf Beach Hotel.
# ------------
# Retrieving Results for Index 278: Kapiri Mposhi.
# Closest hotel in Kapiri Mposhi is Namakuba Lodge.
# ------------
# Retrieving Results for Index 279: Sept-Îles.
# Closest hotel in Sept-Îles is Château Arnaud.
# ------------
# Retrieving Results for Index 280: Rosarito.
# Closest hotel in Rosarito is Rosarito Beach Hotel.
# ------------
# Retrieving Results for Index 281: Vestmannaeyjar.
# Closest hotel in Vestmannaeyjar is Puffin Nest Capsule Hostel.
# ------------
# Retrieving Results for Index 282: Dīdwāna.
# Closest hotel in Dīdwāna is Hotel Didwana Residency.
# ------------
# Retrieving Results for Index 283: Balsas.
# Closest hotel in Balsas is Hotel 10 Balsas.
# ------------
# Retrieving Results for Index 284: Rome.
# Closest hotel in Rome is Wingate By Wyndham Rome.
# ------------
# Retrieving Results for Index 285: Panacan.
# Closest hotel in Panacan is Crystal Paradise Resort.
# ------------
# Retrieving Results for Index 286: Coquimbo.
# Closest hotel in Coquimbo is Enjoy Coquimbo Hotel de la Bahía.
# ------------
# Retrieving Results for Index 287: Dingle.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 288: Ayan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 289: Klaksvík.
# Closest hotel in Klaksvík is Eysturland Lodge.
# ------------
# Retrieving Results for Index 290: Portland.
# Closest hotel in Portland is The Duniway Portland, A Hilton Hotel.
# ------------
# Retrieving Results for Index 291: Vardø.
# Closest hotel in Vardø is Vardø Hotel AS.
# ------------
# Retrieving Results for Index 292: Beloha.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 293: Lavrentiya.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 294: Kem'.
# Closest hotel in Kem' is Kemka.
# ------------
# Retrieving Results for Index 295: Tamala.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 296: Hervey Bay.
# Closest hotel in Hervey Bay is Oaks Hervey Bay Resort and Spa.
# ------------
# Retrieving Results for Index 297: Haines Junction.
# Closest hotel in Haines Junction is Kluane Park Inn & RV Park.
# ------------
# Retrieving Results for Index 298: Carrefour.
# Closest hotel in Carrefour is Auberge du Québec Hôtel.
# ------------
# Retrieving Results for Index 299: Kirakira.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 300: Bekwai.
# Closest hotel in Bekwai is Yeguaa international hotel.
# ------------
# Retrieving Results for Index 301: Flin Flon.
# Closest hotel in Flin Flon is Victoria Inn Flin Flon.
# ------------
# Retrieving Results for Index 302: Vestmanna.
# Closest hotel in Vestmanna is Budget Guesthouse Borgustova.
# ------------
# Retrieving Results for Index 303: Muroto-misakicho.
# Closest hotel in Muroto-misakicho is Misaki Kanko Hotel.
# ------------
# Retrieving Results for Index 304: Mehamn.
# Closest hotel in Mehamn is Mehamn Arctic Hotel AS.
# ------------
# Retrieving Results for Index 305: Touros.
# Closest hotel in Touros is Hotel Vila Gale Touros.
# ------------
# Retrieving Results for Index 306: Masuri.
# Closest hotel in Masuri is Goaeng-Go.
# ------------
# Retrieving Results for Index 307: Airai.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 308: Basse.
# Closest hotel in Basse is Hotel & Restaurant Schulz Neustadt am Rübenberge.
# ------------
# Retrieving Results for Index 309: Soyo.
# Closest hotel in Soyo is Kinwica.
# ------------
# Retrieving Results for Index 310: Mnogovershinnyy.
# Closest hotel in Mnogovershinnyy is Gostinitsa.
# ------------
# Retrieving Results for Index 311: Namatanai.
# Closest hotel in Namatanai is Namatanai Hotel.
# ------------
# Retrieving Results for Index 312: Chadiza.
# Closest hotel in Chadiza is Mweebe Executive Lodge.
# ------------
# Retrieving Results for Index 313: Nanortalik.
# Closest hotel in Nanortalik is Hotel Kap Farvel.
# ------------
# Retrieving Results for Index 314: Netanya.
# Closest hotel in Netanya is Netanya beach short rental apartment.
# ------------
# Retrieving Results for Index 315: Meleuz.
# Closest hotel in Meleuz is Hotel "Agidel".
# ------------
# Retrieving Results for Index 316: Okha.
# Closest hotel in Okha is Empire Hotel.
# ------------
# Retrieving Results for Index 317: Waingapu.
# Closest hotel in Waingapu is Padadita Beach Hotel.
# ------------
# Retrieving Results for Index 318: Miramar.
# Closest hotel in Miramar is Stadium Hotel.
# ------------
# Retrieving Results for Index 319: Dunedin.
# Closest hotel in Dunedin is Wains Hotel Dunedin.
# ------------
# Retrieving Results for Index 320: Atar.
# Closest hotel in Atar is Odar kanawal.
# ------------
# Retrieving Results for Index 321: Gamba.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 322: Micomeseng.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 323: Mossamedes.
# Closest hotel in Mossamedes is Infotur Namibe.
# ------------
# Retrieving Results for Index 324: Bonavista.
# Closest hotel in Bonavista is Russelltown Inn.
# ------------
# Retrieving Results for Index 325: Luganville.
# Closest hotel in Luganville is Village de Santo Resort.
# ------------
# Retrieving Results for Index 326: Pandan.
# Closest hotel in Pandan is Bonifacio Lodge.
# ------------
# Retrieving Results for Index 327: Carnot.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 328: Laas.
# Closest hotel in Laas is Gasthof Zur Sonne.
# ------------
# Retrieving Results for Index 329: Loíza.
# Closest hotel in Loíza is Aquatika.
# ------------
# Retrieving Results for Index 330: Bonthe.
# Closest hotel in Bonthe is Bonthe Holiday Village.
# ------------
# Retrieving Results for Index 331: Tremedal.
# Closest hotel in Tremedal is Educational Center of Tremedal.
# ------------
# Retrieving Results for Index 332: Vila Franca do Campo.
# Closest hotel in Vila Franca do Campo is Pestana Bahia Praia.
# ------------
# Retrieving Results for Index 333: Bilibino.
# Closest hotel in Bilibino is Profilaktoriy Baes.
# ------------
# Retrieving Results for Index 334: Yumen.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 335: Zhuanghe.
# Closest hotel in Zhuanghe is Tianwai Taoyuan.
# ------------
# Retrieving Results for Index 336: Krasnorechenskiy.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 337: Moniquirá.
# Closest hotel in Moniquirá is Hotel Palmeras De Luz.
# ------------
# Retrieving Results for Index 338: Angren.
# Closest hotel in Angren is Пан Азиат.
# ------------
# Retrieving Results for Index 339: Iralaya.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 340: Karratha.
# Closest hotel in Karratha is Latitude20 The Dunes Apartments.
# ------------
# Retrieving Results for Index 341: Macaé.
# Closest hotel in Macaé is Royal Macaé Palace Hotel.
# ------------
# Retrieving Results for Index 342: Lufilufi.
# Closest hotel in Lufilufi is Leuaina Beach Resort and Spa.
# ------------
# Retrieving Results for Index 343: Agirish.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 344: Soldotna.
# Closest hotel in Soldotna is Kenai River Lodge.
# ------------
# Retrieving Results for Index 345: Virden.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 346: Omsukchan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 347: Kalmunai.
# Closest hotel in Kalmunai is LUXEZ garden house.
# ------------
# Retrieving Results for Index 348: Beringovskiy.
# Closest hotel in Beringovskiy is Beringgorski.
# ------------
# Retrieving Results for Index 349: Salalah.
# Closest hotel in Salalah is Salalah Gardens Hotel.
# ------------
# Retrieving Results for Index 350: Kavieng.
# Closest hotel in Kavieng is Nusa Island Retreat.
# ------------
# Retrieving Results for Index 351: Rocha.
# Closest hotel in Rocha is Casa Rodo 53.
# ------------
# Retrieving Results for Index 352: Tiznit Province.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 353: Mandera.
# Closest hotel in Mandera is Granada hotel Mandera.
# ------------
# Retrieving Results for Index 354: Catia La Mar.
# Closest hotel in Catia La Mar is Venezuela Marriott Hotel Playa Grande.
# ------------
# Retrieving Results for Index 355: Hamilton.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 356: Aykhal.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 357: Letlhakane.
# Closest hotel in Letlhakane is Hotel Phudzi.
# ------------
# Retrieving Results for Index 358: Hualmay.
# Closest hotel in Hualmay is Hotel Terrazas Del Mar - Huacho.
# ------------
# Retrieving Results for Index 359: Anjozorobe.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 360: Champerico.
# Closest hotel in Champerico is Hotel Posada del Mar.
# ------------
# Retrieving Results for Index 361: Tateyama.
# Closest hotel in Tateyama is 花しぶき（満開のおもてなし）.
# ------------
# Retrieving Results for Index 362: Barañáin.
# Closest hotel in Barañáin is Pamplona El Toro Hotel & Spa.
# ------------
# Retrieving Results for Index 363: Kapoeta.
# Closest hotel in Kapoeta is Hotel Keleu.
# ------------
# Retrieving Results for Index 364: Hobyo.
# Closest hotel in Hobyo is Osmani Hotel.
# ------------
# Retrieving Results for Index 365: Mīnāb.
# Closest hotel in Mīnāb is Minab Tourism Hotel.
# ------------
# Retrieving Results for Index 366: Grindavik.
# Closest hotel in Grindavik is The Retreat at Blue Lagoon Iceland.
# ------------
# Retrieving Results for Index 367: Takanabe.
# Closest hotel in Takanabe is Hotel AZ Miyazaki Takanabe.
# ------------
# Retrieving Results for Index 368: Nālūt.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 369: Panshi.
# Closest hotel in Panshi is Baiyun Hotel.
# ------------
# Retrieving Results for Index 370: Balkhash.
# Closest hotel in Balkhash is Семейная зона отдыха LAFA.
# ------------
# Retrieving Results for Index 371: Affery.
# Closest hotel in Affery is Hotel Emile Koucou.
# ------------
# Retrieving Results for Index 372: Nome.
# Closest hotel in Nome is Noxapaga Suites.
# ------------
# Retrieving Results for Index 373: Gornyak.
# Closest hotel in Gornyak is Gostinitsa I Kafe "Yubileynaya".
# ------------
# Retrieving Results for Index 374: Vanimo.
# Closest hotel in Vanimo is Sandaun Surf Hotel.
# ------------
# Retrieving Results for Index 375: Sinnamary.
# Closest hotel in Sinnamary is L'oiseau de Paradis.
# ------------
# Retrieving Results for Index 376: Lastoursville.
# Closest hotel in Lastoursville is Hotel Escale De L'ogooue.
# ------------
# Retrieving Results for Index 377: Kailua.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 378: San Miguel de Cozumel.
# Closest hotel in San Miguel de Cozumel is Hotel Cozumel & Resort.
# ------------
# Retrieving Results for Index 379: Conakry.
# Closest hotel in Conakry is Noom Hotel Conakry.
# ------------
# Retrieving Results for Index 380: Talcahuano.
# Closest hotel in Talcahuano is Hotel Terrasur.
# ------------
# Retrieving Results for Index 381: Sooke.
# Closest hotel in Sooke is Prestige Oceanfront Resort, BW Premier Collection.
# ------------
# Retrieving Results for Index 382: Yichun.
# Closest hotel in Yichun is Xinhao Business Hotel.
# ------------
# Retrieving Results for Index 383: Noumea.
# Closest hotel in Noumea is Le Meridien Noumea Resort & Spa.
# ------------
# Retrieving Results for Index 384: Inuvik.
# Closest hotel in Inuvik is Mackenzie Hotel.
# ------------
# Retrieving Results for Index 385: Petropavlovka.
# Closest hotel in Petropavlovka is Tuyaa.
# ------------
# Retrieving Results for Index 386: Huarmey.
# Closest hotel in Huarmey is Hotel Miramar.
# ------------
# Retrieving Results for Index 387: San Quintín.
# Closest hotel in San Quintín is Old Mill Hotel.
# ------------
# Retrieving Results for Index 388: Sertânia.
# Closest hotel in Sertânia is Hotel Esperança.
# ------------
# Retrieving Results for Index 389: Davila.
# Closest hotel in Davila is Blue Ridge Beach Resort.
# ------------
# Retrieving Results for Index 390: Mokshan.
# Closest hotel in Mokshan is AZK Next.
# ------------
# Retrieving Results for Index 391: Mayo.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 392: Halifax.
# Closest hotel in Halifax is The Lord Nelson Hotel & Suites.
# ------------
# Retrieving Results for Index 393: Azle.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 394: San Roque.
# Closest hotel in San Roque is Hotel Admiral Casino & Lodge.
# ------------
# Retrieving Results for Index 395: Wervik.
# Closest hotel in Wervik is Lys Hôtel.
# ------------
# Retrieving Results for Index 396: Dorado.
# Closest hotel in Dorado is Dorado Beach, a Ritz-Carlton Reserve.
# ------------
# Retrieving Results for Index 397: Kumbo.
# Closest hotel in Kumbo is Motel La Residence.
# ------------
# Retrieving Results for Index 398: Arrondissement de Saint-Denis.
# Closest hotel in Arrondissement de Saint-Denis is L'imprimerie hôtel.
# ------------
# Retrieving Results for Index 399: Kyren.
# Closest hotel in Kyren is Tunka-350.
# ------------
# Retrieving Results for Index 400: Oktyabr'skoye.
# Closest hotel in Oktyabr'skoye is Aleksandrovskiy.
# ------------
# Retrieving Results for Index 401: Koungou.
# Closest hotel in Koungou is Hôtel Restaurant Le Trévani.
# ------------
# Retrieving Results for Index 402: Khani.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 403: Kamenka.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 404: Saint-Augustin.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 405: Tual.
# Closest hotel in Tual is Grand Vilia Hotel.
# ------------
# Retrieving Results for Index 406: Russkiy Kameshkir.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 407: Bandarbeyla.
# Closest hotel in Bandarbeyla is Super secret pirate cove.
# ------------
# Retrieving Results for Index 408: Sørkjosen.
# Closest hotel in Sørkjosen is Reisafjord Hotel AS.
# ------------
# Retrieving Results for Index 409: Seoul.
# Closest hotel in Seoul is K-POP HOTEL Seoul Tower.
# ------------
# Retrieving Results for Index 410: Yulara.
# Closest hotel in Yulara is Ayers Rock Resort.
# ------------
# Retrieving Results for Index 411: Pombas.
# Closest hotel in Pombas is Tienne Del Mar.
# ------------
# Retrieving Results for Index 412: Oriximiná.
# Closest hotel in Oriximiná is Castanheira Hotel.
# ------------
# Retrieving Results for Index 413: Esperance.
# Closest hotel in Esperance is The Jetty Resort.
# ------------
# Retrieving Results for Index 414: Mattru.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 415: Harper.
# Closest hotel in Harper is Grands' Guesthouse.
# ------------
# Retrieving Results for Index 416: Loreto.
# Closest hotel in Loreto is Miguel Angel Hotel.
# ------------
# Retrieving Results for Index 417: Olinda.
# Closest hotel in Olinda is Pousada do Amparo.
# ------------
# Retrieving Results for Index 418: Tromsø.
# Closest hotel in Tromsø is Scandic Ishavshotel.
# ------------
# Retrieving Results for Index 419: Kalmar.
# Closest hotel in Kalmar is Hotell Hilda.
# ------------
# Retrieving Results for Index 420: Trairi.
# Closest hotel in Trairi is Rede Beach: Hotel em Guajiru.
# ------------
# Retrieving Results for Index 421: Lyngseidet.
# Closest hotel in Lyngseidet is Magic Mountain Lodge.
# ------------
# Retrieving Results for Index 422: Jiuquan.
# Closest hotel in Jiuquan is Jiuquan Hotel.
# ------------
# Retrieving Results for Index 423: Dom Pedro.
# Closest hotel in Dom Pedro is Pousada Santa Amália.
# ------------
# Retrieving Results for Index 424: Malindi.
# Closest hotel in Malindi is Diamonds Dream of Africa.
# ------------
# Retrieving Results for Index 425: Burnie.
# Closest hotel in Burnie is Beachfront Voyager Motor Inn.
# ------------
# Retrieving Results for Index 426: Mmabatho.
# Closest hotel in Mmabatho is Peermont Walmont Hotel at Mmabatho Palms.
# ------------
# Retrieving Results for Index 427: Praia.
# Closest hotel in Praia is Hotel Oasis Atlantico Praiamar.
# ------------
# Retrieving Results for Index 428: Allāpalli.
# Closest hotel in Allāpalli is Hotel IK Residency.
# ------------
# Retrieving Results for Index 429: Corrente.
# Closest hotel in Corrente is the Sun Tower Hotel.
# ------------
# Retrieving Results for Index 430: Caborca.
# Closest hotel in Caborca is Hotel Elba.
# ------------
# Retrieving Results for Index 431: Walvis Bay.
# Closest hotel in Walvis Bay is Flamingo Villas Boutique Hotel.
# ------------
# Retrieving Results for Index 432: Larsnes.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 433: Inverness.
# Closest hotel in Inverness is Bunchrew House.
# ------------
# Retrieving Results for Index 434: Ojinaga.
# Closest hotel in Ojinaga is Riata Inn Presidio.
# ------------
# Retrieving Results for Index 435: Örnsköldsvik.
# Closest hotel in Örnsköldsvik is Elite Plaza Hotel Örnsköldsvik.
# ------------
# Retrieving Results for Index 436: Tandaltī.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 437: San Francisco.
# Closest hotel in San Francisco is San Francisco Proper.
# ------------
# Retrieving Results for Index 438: Half Moon Bay.
# Closest hotel in Half Moon Bay is Beach House - Half Moon Bay.
# ------------
# Retrieving Results for Index 439: Garoowe.
# Closest hotel in Garoowe is Curubo Hotel.
# ------------
# Retrieving Results for Index 440: Pocatello.
# Closest hotel in Pocatello is Black Swan Inn.
# ------------
# Retrieving Results for Index 441: Tawang Town.
# Closest hotel in Tawang Town is Hotel Happy Valley.
# ------------
# Retrieving Results for Index 442: Cochrane.
# Closest hotel in Cochrane is Rockyview Hotel.
# ------------
# Retrieving Results for Index 443: Ambilobe.
# Closest hotel in Ambilobe is Hotel National.
# ------------
# Retrieving Results for Index 444: Uruçuí.
# Closest hotel in Uruçuí is Formula Flat Uruçui.
# ------------
# Retrieving Results for Index 445: Bethel.
# Closest hotel in Bethel is Courtyard by Marriott Danbury.
# ------------
# Retrieving Results for Index 446: Tila.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 447: Tignère.
# Closest hotel in Tignère is Hotel Famanou.
# ------------
# Retrieving Results for Index 448: Simbahan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 449: Garden City.
# Closest hotel in Garden City is Staybridge Suites Dearborn MI.
# ------------
# Retrieving Results for Index 450: Santa Cruz de la Sierra.
# Closest hotel in Santa Cruz de la Sierra is Marriott Santa Cruz de la Sierra Hotel.
# ------------
# Retrieving Results for Index 451: General Bravo.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 452: Estelle.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 453: Kupang.
# Closest hotel in Kupang is ASTON Kupang Hotel & Convention Center.
# ------------
# Retrieving Results for Index 454: Smoky Lake.
# Closest hotel in Smoky Lake is Super 8 by Wyndham Smoky Lake.
# ------------
# Retrieving Results for Index 455: Zhangye.
# Closest hotel in Zhangye is XiYu International Hotel.
# ------------
# Retrieving Results for Index 456: Santa Cruz.
# Closest hotel in Santa Cruz is Iberostar Founty Beach.
# ------------
# Retrieving Results for Index 457: Marand.
# Closest hotel in Marand is Marand Tourist Hotel.
# ------------
# Retrieving Results for Index 458: Silvassa.
# Closest hotel in Silvassa is VITS Kamats - Silvassa.
# ------------
# Retrieving Results for Index 459: Beya.
# Closest hotel in Beya is Sberbank Rossii.
# ------------
# Retrieving Results for Index 460: Ruska Poliana.
# Closest hotel in Ruska Poliana is Vershnyk.
# ------------
# Retrieving Results for Index 461: Riviere-au-Renard.
# Closest hotel in Riviere-au-Renard is Auberge Le Caribou.
# ------------
# Retrieving Results for Index 462: Esmeralda.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 463: Dawson Creek.
# Closest hotel in Dawson Creek is Stonebridge Hotel Dawson Creek.
# ------------
# Retrieving Results for Index 464: Wilmington.
# Closest hotel in Wilmington is Hotel Ballast Wilmington, Tapestry Collection by Hilton.
# ------------
# Retrieving Results for Index 465: Salinópolis.
# Closest hotel in Salinópolis is Hotel Concha do Mar.
# ------------
# Retrieving Results for Index 466: Caravelas.
# Closest hotel in Caravelas is Mar Doce de Abrolhos.
# ------------
# Retrieving Results for Index 467: Port Blair.
# Closest hotel in Port Blair is Symphony Samudra, Port Blair.
# ------------
# Retrieving Results for Index 468: Tonota.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 469: Dolisie.
# Closest hotel in Dolisie is La Dolisienne.
# ------------
# Retrieving Results for Index 470: San Jeronimito.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 471: Bantry.
# Closest hotel in Bantry is The Maritime Hotel.
# ------------
# Retrieving Results for Index 472: Port Hawkesbury.
# Closest hotel in Port Hawkesbury is Maritime Inn Port Hawkesbury.
# ------------
# Retrieving Results for Index 473: Kiama.
# Closest hotel in Kiama is Nova Kiama.
# ------------
# Retrieving Results for Index 474: Srednekolymsk.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 475: Petropavlovsk-Kamchatskiy.
# Closest hotel in Petropavlovsk-Kamchatskiy is Hotel Arsenev.
# ------------
# Retrieving Results for Index 476: Kirensk.
# Closest hotel in Kirensk is Kirenskiy Plos.
# ------------
# Retrieving Results for Index 477: Obo.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 478: Jasper.
# Closest hotel in Jasper is Best Budget Inn.
# ------------
# Retrieving Results for Index 479: Areia Branca.
# Closest hotel in Areia Branca is HOTEL COSTA ATLÂNTICO.
# ------------
# Retrieving Results for Index 480: Mungaoli.
# Closest hotel in Mungaoli is Amit Lodge.
# ------------
# Retrieving Results for Index 481: Nizhnyaya Tavda.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 482: Marfino.
# Closest hotel in Marfino is Pamir - Tyan-Shan Hotel.
# ------------
# Retrieving Results for Index 483: Wajima.
# Closest hotel in Wajima is Hotel Route-Inn Wajima.
# ------------
# Retrieving Results for Index 484: Lagos.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 485: Northam.
# Closest hotel in Northam is Durrant House Hotel.
# ------------
# Retrieving Results for Index 486: Buin.
# Closest hotel in Buin is Paihuen.
# ------------
# Retrieving Results for Index 487: Lerwick.
# Closest hotel in Lerwick is The Queens Hotel, Lerwick.
# ------------
# Retrieving Results for Index 488: Grand-Lahou.
# Closest hotel in Grand-Lahou is Hotel Beatitude de Grand Lahou.
# ------------
# Retrieving Results for Index 489: Krasnosel'kup.
# Closest hotel in Krasnosel'kup is Krasnosel'kupnefteprodukt.
# ------------
# Retrieving Results for Index 490: Acapulco de Juárez.
# Closest hotel in Acapulco de Juárez is Dreams Acapulco Resort & Spa.
# ------------
# Retrieving Results for Index 491: São João da Barra.
# Closest hotel in São João da Barra is Pousada Kactus.
# ------------
# Retrieving Results for Index 492: Owando.
# Closest hotel in Owando is Hotel MOMBO Beach Owando.
# ------------
# Retrieving Results for Index 493: Kazanka.
# Closest hotel in Kazanka is Готель.
# ------------
# Retrieving Results for Index 494: Ekhabi.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 495: Pekan Nenas.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 496: Smithers.
# Closest hotel in Smithers is Prestige Hudson Bay Lodge.
# ------------
# Retrieving Results for Index 497: Kidal.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 498: Playas.
# Closest hotel in Playas is Playa Paraíso Gastronomía & Lodge.
# ------------
# Retrieving Results for Index 499: New Philadelphia.
# Closest hotel in New Philadelphia is Holiday Inn Express & Suites New Philadelphia.
# ------------
# Retrieving Results for Index 500: Ilulissat.
# Closest hotel in Ilulissat is Hotel Arctic.
# ------------
# Retrieving Results for Index 501: Tonekābon.
# Closest hotel in Tonekābon is Mahan Hostel.
# ------------
# Retrieving Results for Index 502: Leningradskiy.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 503: Cruzeiro do Sul.
# Closest hotel in Cruzeiro do Sul is Estrela Palace Hotel.
# ------------
# Retrieving Results for Index 504: Fochabers.
# Closest hotel in Fochabers is The Mill House Hotel.
# ------------
# Retrieving Results for Index 505: Khāsh.
# Closest hotel in Khāsh is خوابگاه دانشجویی خاش.
# ------------
# Retrieving Results for Index 506: Atbasar.
# Closest hotel in Atbasar is The Ritz-Carlton, Astana.
# ------------
# Retrieving Results for Index 507: Ipixuna.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 508: Sassandra.
# Closest hotel in Sassandra is JOYAU CACHÉ.
# ------------
# Retrieving Results for Index 509: Tolaga Bay.
# Closest hotel in Tolaga Bay is Tolaga Bay Inn.
# ------------
# Retrieving Results for Index 510: Sydney.
# Closest hotel in Sydney is Shangri-La Hotel, Sydney.
# ------------
# Retrieving Results for Index 511: Klyuchi.
# Closest hotel in Klyuchi is Vesolaya Mayovka.
# ------------
# Retrieving Results for Index 512: San Jose.
# Closest hotel in San Jose is Fairmont San Jose.
# ------------
# Retrieving Results for Index 513: Kaitangata.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 514: Ukiah.
# Closest hotel in Ukiah is Hampton Inn Ukiah.
# ------------
# Retrieving Results for Index 515: Clyde River.
# Closest hotel in Clyde River is Naujaaraaluit – Clyde River Hotel.
# ------------
# -------End of Search-------

# %%
hotel_df
# Out:
#             City Country    Lat     Lng                         Hotel Name
# 0         Avarua      CK -21.21 -159.78       The Edgewater Resort and Spa
# 1    Provideniya      RU  64.38 -173.30
# 2         Murgab      TM  37.50   61.97
# 3      Geraldton      AU -28.77  114.60                 Ocean Centre Hotel
# 4      Busselton      AU -33.65  115.33                    Esplanade Hotel
# ..           ...     ...    ...     ...                                ...
# 511      Klyuchi      RU  52.27   79.17                   Vesolaya Mayovka
# 512     San Jose      US  37.34 -121.89                  Fairmont San Jose
# 513   Kaitangata      NZ -46.28  169.85
# 514        Ukiah      US  39.15 -123.21                  Hampton Inn Ukiah
# 515  Clyde River      CA  70.47  -68.59  Naujaaraaluit – Clyde River Hotel
#
# [516 rows x 5 columns]

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer and info box content ontop of heat map
markers = gmaps.marker_layer(locations, info_box_content = hotel_info)

# Add the layer to the map
fig.add_layer(markers)

# Display Map
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
